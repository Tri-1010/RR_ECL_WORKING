# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\MAFC4709\\.conda\\envs\\rrmodel\\python.exe'

# %%
jupyter kernelspec list
# Out:
#   Cell In[2], line 1
#     jupyter kernelspec list
#             ^
# SyntaxError: invalid syntax

# %%
import os
os.path.abspath('.')
# Out:
# 'C:\\Users\\MAFC4709\\Python_work\\RR_model\\notebooks'
