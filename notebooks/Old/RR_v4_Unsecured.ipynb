# %%
# %load_ext autoreload
# %autoreload 2

# %%
# ============================================================
# ✅ FIX PATH FOR NOTEBOOK INSIDE /notebooks
# ============================================================
import sys, os
from pathlib import Path

# Xác định thư mục cha của notebooks/
project_root = Path(os.getcwd()).parent  # => C:\Users\User\RR_model
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))  # ⚠️ thêm project_root, KHÔNG thêm src

print("📁 Project root added:", project_root)

# Kiểm tra lại
import importlib.util
print("🔍 src module found:", importlib.util.find_spec("src"))
# Out:
# 📁 Project root added: D:\Python_code\RR_model_1711
# 🔍 src module found: ModuleSpec(name='src', loader=<_frozen_importlib_external.SourceFileLoader object at 0x00000250FF391900>, origin='D:\\Python_code\\RR_model_1711\\src\\__init__.py', submodule_search_locations=['D:\\Python_code\\RR_model_1711\\src'])

# %%
# ===========================================================
# 📘 Roll Rate Demo v7 - Sử dụng dữ liệu thật từ Oracle hoặc SQL file
# ===========================================================

from pathlib import Path
import sys
import pandas as pd
import numpy as np

# --- 1️⃣ Setup đường dẫn và import các module ---
root = Path(".").resolve()
sys.path.append(str(root / "src"))

from src.data_loader import load_data
from src.config import CFG, OUT_ROOT
from src.rollrate.transition import compute_transition_from_pairs, compute_transition_by_mob
#from src.rollrate.forecast import forecast_report
from src.rollrate.export_excel import export_transition_excel
from src.rollrate.backtest import (
    compute_actual_matrix,
    rollforward_validation,
    plot_matrix_diff,
    plot_distribution_compare
)

print("✅ Import modules thành công.")
print("Cấu hình CFG:", CFG)


# --- 2️⃣ Load dữ liệu thực tế ---
sql_path = r"D:\Python_code\RR_Model_1711\sql\uns3.sql"

df = load_data(sql_path)
# df = load_data()
df['DISBURSAL_DATE'] = df['DISBURSAL_DATE'].apply(lambda x: x.replace(day=1))

#print(f"📦 Đã load {len(df):,} dòng dữ liệu từ {sql_path}")

# Kiểm tra các cột quan trọng
required_cols = [CFG["loan"], CFG["mob"], CFG["state"], CFG["ead"], CFG["cutoff"]]
missing = [c for c in required_cols if c not in df.columns]
if missing:
    raise ValueError(f"❌ Thiếu các cột cần thiết trong data: {missing}")

print("✅ Dữ liệu có đủ các cột cần thiết:", required_cols)

# Nếu chưa có PRODUCT_TYPE thì thêm mặc định
if "PRODUCT_TYPE" not in df.columns:
    df["PRODUCT_TYPE"] = "A"
    print("⚠️ Không có PRODUCT_TYPE trong data, gán mặc định = 'A'")

# Convert cutoff về datetime
df[CFG["cutoff"]] = pd.to_datetime(df[CFG["cutoff"]])
# Out:
# ✅ Import modules thành công.
# Cấu hình CFG: {'loan': 'AGREEMENT_ID', 'mob': 'MOB', 'state': 'STATE_MODEL', 'orig_date': 'DISBURSAL_DATE', 'ead': 'PRINCIPLE_OUTSTANDING', 'disb': 'DISBURSAL_AMOUNT', 'cutoff': 'CUTOFF_DATE'}
# 🔗 Loading data from Oracle...
# === SQL DEBUG ===
# File: D:\Python_code\RR_Model_1711\sql\uns3.sql
# First 200 chars:
#  select * from TBL_RR_UNSECURED3
# Params: {}
# =================
# D:\Python_code\RR_model_1711\src\db.py:84: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(
# 🔗 Loading data from Oracle...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 34
#      31 sql_path = r"D:\Python_code\RR_Model_1711\sql\uns3.sql"
#      33 df = load_data(sql_path)
# ---> 34 df = load_data()
#      35 df['DISBURSAL_DATE'] = df['DISBURSAL_DATE'].apply(lambda x: x.replace(day=1))
#      37 #print(f"📦 Đã load {len(df):,} dòng dữ liệu từ {sql_path}")
#      38
#      39 # Kiểm tra các cột quan trọng
#
# File D:\Python_code\RR_model_1711\src\data_loader.py:39, in load_data(sql_or_file, params)
#      37     print("🔗 Loading data from Oracle...")
#      38     if sql_or_file is None:
# ---> 39         raise ValueError("Cần chỉ định tên SQL file hoặc câu SQL khi dùng Oracle.")
#      40     return load_df(sql_or_file, params=params)
#      42 # ------------------- Parquet -------------------
#
# ValueError: Cần chỉ định tên SQL file hoặc câu SQL khi dùng Oracle.

# %%
df['DISBURSAL_DATE'] = df['DISBURSAL_DATE'].apply(lambda x: x.replace(day=1))

#print(f"📦 Đã load {len(df):,} dòng dữ liệu từ {sql_path}")

# Kiểm tra các cột quan trọng
required_cols = [CFG["loan"], CFG["mob"], CFG["state"], CFG["ead"], CFG["cutoff"]]
missing = [c for c in required_cols if c not in df.columns]
if missing:
    raise ValueError(f"❌ Thiếu các cột cần thiết trong data: {missing}")

print("✅ Dữ liệu có đủ các cột cần thiết:", required_cols)

# Nếu chưa có PRODUCT_TYPE thì thêm mặc định
if "PRODUCT_TYPE" not in df.columns:
    df["PRODUCT_TYPE"] = "A"
    print("⚠️ Không có PRODUCT_TYPE trong data, gán mặc định = 'A'")

# Convert cutoff về datetime
df[CFG["cutoff"]] = pd.to_datetime(df[CFG["cutoff"]])
# Out:
# ✅ Dữ liệu có đủ các cột cần thiết: ['AGREEMENT_ID', 'MOB', 'STATE_MODEL', 'PRINCIPLE_OUTSTANDING', 'CUTOFF_DATE']

# %%
from src.rollrate.transition import compute_transition_by_mob
from src.rollrate.export_excel import export_transition_excel
from src.config import OUT_ROOT

print("\n=== Tính transition matrices theo Product × MOB × Score ===")
matrices_by_mob, parent_fallback = compute_transition_by_mob(df)

# Đếm real vs fallback
count_real = 0
count_fb = 0

for prod, mob_dict in matrices_by_mob.items():
    for mob, score_dict in mob_dict.items():
        for score, obj in score_dict.items():
            if obj["is_fallback"]:
                count_fb += 1
            else:
                count_real += 1

print(f"🔹 Ma trận REAL     : {count_real}")
print(f"🔸 Ma trận FALLBACK : {count_fb}")
print(f"🔢 Tổng             : {count_real + count_fb}")

# Xuất Excel
export_transition_excel(
    matrices_by_mob,
    parent_fallback,
    out_path=OUT_ROOT / "Transition_ByProduct_MOB_Score_2.xlsx"
)
# Out:
# === Tính transition matrices theo Product × MOB × Score ===
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=CDLPIL, score=500-)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=CDLPIL, score=550-)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=CDLPIL, score=600-)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=CDLPIL, score=650+)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=CDLPIL, score=650-)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=CDLPIL, score=OTHERS)
# ⚠️ Có 3 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SALPIL, score=A)
# ⚠️ Có 3 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SALPIL, score=B)
# ⚠️ Có 3 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SALPIL, score=C)
# ⚠️ Có 3 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SALPIL, score=D)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SPLPIL, score=500-)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SPLPIL, score=550-)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SPLPIL, score=600-)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SPLPIL, score=650+)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SPLPIL, score=650-)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=SPLPIL, score=OTHERS)
# ⚠️ Có 3 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TOPPIL, score=A)
# ⚠️ Có 3 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TOPPIL, score=B)
# ⚠️ Có 3 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TOPPIL, score=C)
# ⚠️ Có 3 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TOPPIL, score=D)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TWLPIL, score=500-)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TWLPIL, score=550-)
# ⚠️ Có 5 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'WRITEOFF', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TWLPIL, score=600-)
# ⚠️ Có 5 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'WRITEOFF', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TWLPIL, score=650+)
# ⚠️ Có 5 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'WRITEOFF', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TWLPIL, score=650-)
# ⚠️ Có 5 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'WRITEOFF', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=TWLPIL, score=OTHERS)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=XSELL, score=A)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=XSELL, score=B)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=XSELL, score=C)
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚙️ Built parent fallback for (product=XSELL, score=D)
# ⚠️ Có 8 hàng có tổng weight = 0: ['DPD30+', 'DPD60+', 'DPD90+', 'DPD120+', 'DPD180+', 'PREPAY', 'WRITEOFF', 'SOLDOUT']
# ⚠️ Có 7 hàng có tổng weight = 0: ['DPD60+', 'DPD90+', 'DPD120+', 'DPD180+', 'PREPAY', 'WRITEOFF', 'SOLDOUT']
# ⚠️ Có 6 hàng có tổng weight = 0: ['DPD90+', 'DPD120+', 'DPD180+', 'PREPAY', 'WRITEOFF', 'SOLDOUT']
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚠️ Có 4 hàng có tổng weight = 0: ['DPD120+', 'DPD180+', 'PREPAY', 'SOLDOUT']
# ⚠️ Fallback MOB=5 for (product=CDLPIL, score=500-) → insufficient data (n_obs=127459, total_ead=978,312)
# ⚠️ Fallback MOB=6 for (product=CDLPIL, score=500-) → insufficient data (n_obs=116510, total_ead=864,819)
# ⚠️ Fallback MOB=7 for (product=CDLPIL, score=500-) → insufficient data (n_obs=107463, total_ead=779,438)
# ⚠️ Fallback MOB=8 for (product=CDLPIL, score=500-) → insufficient data (n_obs=93753, total_ead=618,804)
# ⚠️ Fallback MOB=9 for (product=CDLPIL, score=500-) → insufficient data (n_obs=78730, total_ead=444,884)
# ⚠️ Fallback MOB=10 for (product=CDLPIL, score=500-) → insufficient data (n_obs=67522, total_ead=336,786)
# ⚠️ Fallback MOB=11 for (product=CDLPIL, score=500-) → insufficient data (n_obs=56739, total_ead=241,204)
# ⚠️ Fallback MOB=12 for (product=CDLPIL, score=500-) → insufficient data (n_obs=47354, total_ead=179,314)
# ⚠️ Fallback MOB=13 for (product=CDLPIL, score=500-) → insufficient data (n_obs=39806, total_ead=143,798)
# ⚠️ Fallback MOB=14 for (product=CDLPIL, score=500-) → insufficient data (n_obs=34464, total_ead=118,991)
# ⚠️ Fallback MOB=15 for (product=CDLPIL, score=500-) → insufficient data (n_obs=30397, total_ead=103,272)
# ⚠️ Fallback MOB=16 for (product=CDLPIL, score=500-) → insufficient data (n_obs=27410, total_ead=93,293)
# ⚠️ Fallback MOB=17 for (product=CDLPIL, score=500-) → insufficient data (n_obs=24775, total_ead=83,785)
# ⚠️ Fallback MOB=18 for (product=CDLPIL, score=500-) → insufficient data (n_obs=22231, total_ead=73,203)
# ⚠️ Fallback MOB=19 for (product=CDLPIL, score=500-) → insufficient data (n_obs=19783, total_ead=66,182)
# ⚠️ Fallback MOB=20 for (product=CDLPIL, score=500-) → insufficient data (n_obs=15489, total_ead=48,505)
# ⚠️ Fallback MOB=21 for (product=CDLPIL, score=500-) → insufficient data (n_obs=12122, total_ead=36,385)
# ⚠️ Fallback MOB=22 for (product=CDLPIL, score=500-) → insufficient data (n_obs=9442, total_ead=26,983)
# ⚠️ Fallback MOB=23 for (product=CDLPIL, score=500-) → insufficient data (n_obs=7109, total_ead=18,014)
# ⚠️ Fallback MOB=0 for (product=CDLPIL, score=550-) → insufficient data (n_obs=113169, total_ead=915,928)
# ⚠️ Fallback MOB=1 for (product=CDLPIL, score=550-) → insufficient data (n_obs=111962, total_ead=843,746)
# ⚠️ Fallback MOB=2 for (product=CDLPIL, score=550-) → insufficient data (n_obs=109898, total_ead=773,893)
# ⚠️ Fallback MOB=3 for (product=CDLPIL, score=550-) → insufficient data (n_obs=107063, total_ead=704,648)
# ⚠️ Fallback MOB=4 for (product=CDLPIL, score=550-) → insufficient data (n_obs=102858, total_ead=630,269)
# ⚠️ Fallback MOB=5 for (product=CDLPIL, score=550-) → insufficient data (n_obs=97887, total_ead=553,663)
# ⚠️ Fallback MOB=6 for (product=CDLPIL, score=550-) → insufficient data (n_obs=92420, total_ead=476,125)
# ⚠️ Fallback MOB=7 for (product=CDLPIL, score=550-) → insufficient data (n_obs=87989, total_ead=417,339)
# ⚠️ Fallback MOB=8 for (product=CDLPIL, score=550-) → insufficient data (n_obs=80984, total_ead=320,155)
# ⚠️ Fallback MOB=9 for (product=CDLPIL, score=550-) → insufficient data (n_obs=74101, total_ead=235,418)
# ⚠️ Fallback MOB=10 for (product=CDLPIL, score=550-) → insufficient data (n_obs=67592, total_ead=178,082)
# ⚠️ Fallback MOB=11 for (product=CDLPIL, score=550-) → insufficient data (n_obs=60880, total_ead=125,682)
# ⚠️ Fallback MOB=12 for (product=CDLPIL, score=550-) → insufficient data (n_obs=54806, total_ead=92,789)
# ⚠️ Fallback MOB=13 for (product=CDLPIL, score=550-) → insufficient data (n_obs=49683, total_ead=80,505)
# ⚠️ Fallback MOB=14 for (product=CDLPIL, score=550-) → insufficient data (n_obs=45756, total_ead=73,019)
# ⚠️ Fallback MOB=15 for (product=CDLPIL, score=550-) → insufficient data (n_obs=42266, total_ead=66,714)
# ⚠️ Fallback MOB=16 for (product=CDLPIL, score=550-) → insufficient data (n_obs=39824, total_ead=63,048)
# ⚠️ Fallback MOB=17 for (product=CDLPIL, score=550-) → insufficient data (n_obs=37664, total_ead=60,398)
# ⚠️ Fallback MOB=18 for (product=CDLPIL, score=550-) → insufficient data (n_obs=35527, total_ead=57,075)
# ⚠️ Fallback MOB=19 for (product=CDLPIL, score=550-) → insufficient data (n_obs=32298, total_ead=54,702)
# ⚠️ Fallback MOB=20 for (product=CDLPIL, score=550-) → insufficient data (n_obs=27381, total_ead=47,252)
# ⚠️ Fallback MOB=21 for (product=CDLPIL, score=550-) → insufficient data (n_obs=23209, total_ead=41,257)
# ⚠️ Fallback MOB=22 for (product=CDLPIL, score=550-) → insufficient data (n_obs=19525, total_ead=36,318)
# ⚠️ Fallback MOB=23 for (product=CDLPIL, score=550-) → insufficient data (n_obs=16043, total_ead=30,909)
# ⚠️ Fallback MOB=0 for (product=CDLPIL, score=600-) → insufficient data (n_obs=102199, total_ead=767,569)
# ⚠️ Fallback MOB=1 for (product=CDLPIL, score=600-) → insufficient data (n_obs=101980, total_ead=698,011)
# ⚠️ Fallback MOB=2 for (product=CDLPIL, score=600-) → insufficient data (n_obs=101250, total_ead=631,711)
# ⚠️ Fallback MOB=3 for (product=CDLPIL, score=600-) → insufficient data (n_obs=99849, total_ead=562,241)
# ⚠️ Fallback MOB=4 for (product=CDLPIL, score=600-) → insufficient data (n_obs=97697, total_ead=488,338)
# ⚠️ Fallback MOB=5 for (product=CDLPIL, score=600-) → insufficient data (n_obs=94717, total_ead=410,975)
# ⚠️ Fallback MOB=6 for (product=CDLPIL, score=600-) → insufficient data (n_obs=91312, total_ead=336,322)
# ⚠️ Fallback MOB=7 for (product=CDLPIL, score=600-) → insufficient data (n_obs=88358, total_ead=281,545)
# ⚠️ Fallback MOB=8 for (product=CDLPIL, score=600-) → insufficient data (n_obs=83969, total_ead=207,046)
# ⚠️ Fallback MOB=9 for (product=CDLPIL, score=600-) → insufficient data (n_obs=79302, total_ead=144,659)
# ⚠️ Fallback MOB=10 for (product=CDLPIL, score=600-) → insufficient data (n_obs=74742, total_ead=108,330)
# ⚠️ Fallback MOB=11 for (product=CDLPIL, score=600-) → insufficient data (n_obs=70027, total_ead=76,454)
# ⚠️ Fallback MOB=12 for (product=CDLPIL, score=600-) → insufficient data (n_obs=65587, total_ead=56,061)
# ⚠️ Fallback MOB=13 for (product=CDLPIL, score=600-) → insufficient data (n_obs=61250, total_ead=51,421)
# ⚠️ Fallback MOB=14 for (product=CDLPIL, score=600-) → insufficient data (n_obs=58529, total_ead=48,916)
# ⚠️ Fallback MOB=15 for (product=CDLPIL, score=600-) → insufficient data (n_obs=55817, total_ead=46,071)
# ⚠️ Fallback MOB=16 for (product=CDLPIL, score=600-) → insufficient data (n_obs=53671, total_ead=44,351)
# ⚠️ Fallback MOB=17 for (product=CDLPIL, score=600-) → insufficient data (n_obs=51920, total_ead=43,276)
# ⚠️ Fallback MOB=18 for (product=CDLPIL, score=600-) → insufficient data (n_obs=50470, total_ead=42,118)
# ⚠️ Fallback MOB=19 for (product=CDLPIL, score=600-) → insufficient data (n_obs=47093, total_ead=41,898)
# ⚠️ Fallback MOB=20 for (product=CDLPIL, score=600-) → insufficient data (n_obs=42306, total_ead=38,493)
# ⚠️ Fallback MOB=21 for (product=CDLPIL, score=600-) → insufficient data (n_obs=37449, total_ead=35,231)
# ⚠️ Fallback MOB=22 for (product=CDLPIL, score=600-) → insufficient data (n_obs=32908, total_ead=32,640)
# ⚠️ Fallback MOB=23 for (product=CDLPIL, score=600-) → insufficient data (n_obs=28384, total_ead=29,368)
# ⚠️ Fallback MOB=0 for (product=CDLPIL, score=650+) → insufficient data (n_obs=98889, total_ead=638,268)
# ⚠️ Fallback MOB=1 for (product=CDLPIL, score=650+) → insufficient data (n_obs=98403, total_ead=553,057)
# ⚠️ Fallback MOB=2 for (product=CDLPIL, score=650+) → insufficient data (n_obs=97803, total_ead=467,388)
# ⚠️ Fallback MOB=3 for (product=CDLPIL, score=650+) → insufficient data (n_obs=96385, total_ead=378,471)
# ⚠️ Fallback MOB=4 for (product=CDLPIL, score=650+) → insufficient data (n_obs=95029, total_ead=289,985)
# ⚠️ Fallback MOB=5 for (product=CDLPIL, score=650+) → insufficient data (n_obs=93133, total_ead=199,075)
# ⚠️ Fallback MOB=6 for (product=CDLPIL, score=650+) → insufficient data (n_obs=91092, total_ead=116,151)
# ⚠️ Fallback MOB=7 for (product=CDLPIL, score=650+) → insufficient data (n_obs=89213, total_ead=85,621)
# ⚠️ Fallback MOB=8 for (product=CDLPIL, score=650+) → insufficient data (n_obs=86023, total_ead=53,332)
# ⚠️ Fallback MOB=9 for (product=CDLPIL, score=650+) → insufficient data (n_obs=82396, total_ead=28,068)
# ⚠️ Fallback MOB=10 for (product=CDLPIL, score=650+) → insufficient data (n_obs=78816, total_ead=20,057)
# ⚠️ Fallback MOB=11 for (product=CDLPIL, score=650+) → insufficient data (n_obs=75475, total_ead=13,627)
# ⚠️ Fallback MOB=12 for (product=CDLPIL, score=650+) → insufficient data (n_obs=72545, total_ead=9,633)
# ⚠️ Fallback MOB=13 for (product=CDLPIL, score=650+) → insufficient data (n_obs=70111, total_ead=9,713)
# ⚠️ Fallback MOB=14 for (product=CDLPIL, score=650+) → insufficient data (n_obs=70658, total_ead=10,272)
# ⚠️ Fallback MOB=15 for (product=CDLPIL, score=650+) → insufficient data (n_obs=72143, total_ead=10,416)
# ⚠️ Fallback MOB=16 for (product=CDLPIL, score=650+) → insufficient data (n_obs=74599, total_ead=10,840)
# ⚠️ Fallback MOB=17 for (product=CDLPIL, score=650+) → insufficient data (n_obs=76777, total_ead=11,432)
# ⚠️ Fallback MOB=18 for (product=CDLPIL, score=650+) → insufficient data (n_obs=79220, total_ead=12,026)
# ⚠️ Fallback MOB=19 for (product=CDLPIL, score=650+) → insufficient data (n_obs=78900, total_ead=12,730)
# ⚠️ Fallback MOB=20 for (product=CDLPIL, score=650+) → insufficient data (n_obs=82862, total_ead=13,120)
# ⚠️ Fallback MOB=21 for (product=CDLPIL, score=650+) → insufficient data (n_obs=77852, total_ead=12,983)
# ⚠️ Fallback MOB=22 for (product=CDLPIL, score=650+) → insufficient data (n_obs=73173, total_ead=13,025)
# ⚠️ Fallback MOB=23 for (product=CDLPIL, score=650+) → insufficient data (n_obs=68104, total_ead=12,895)
# ⚠️ Fallback MOB=0 for (product=CDLPIL, score=650-) → insufficient data (n_obs=81394, total_ead=566,306)
# ⚠️ Fallback MOB=1 for (product=CDLPIL, score=650-) → insufficient data (n_obs=81340, total_ead=505,073)
# ⚠️ Fallback MOB=2 for (product=CDLPIL, score=650-) → insufficient data (n_obs=81107, total_ead=445,748)
# ⚠️ Fallback MOB=3 for (product=CDLPIL, score=650-) → insufficient data (n_obs=80289, total_ead=382,540)
# ⚠️ Fallback MOB=4 for (product=CDLPIL, score=650-) → insufficient data (n_obs=79305, total_ead=317,989)
# ⚠️ Fallback MOB=5 for (product=CDLPIL, score=650-) → insufficient data (n_obs=77658, total_ead=250,263)
# ⚠️ Fallback MOB=6 for (product=CDLPIL, score=650-) → insufficient data (n_obs=75535, total_ead=184,693)
# ⚠️ Fallback MOB=7 for (product=CDLPIL, score=650-) → insufficient data (n_obs=73920, total_ead=147,135)
# ⚠️ Fallback MOB=8 for (product=CDLPIL, score=650-) → insufficient data (n_obs=71326, total_ead=101,655)
# ⚠️ Fallback MOB=9 for (product=CDLPIL, score=650-) → insufficient data (n_obs=68204, total_ead=64,520)
# ⚠️ Fallback MOB=10 for (product=CDLPIL, score=650-) → insufficient data (n_obs=65217, total_ead=48,189)
# ⚠️ Fallback MOB=11 for (product=CDLPIL, score=650-) → insufficient data (n_obs=62339, total_ead=33,600)
# ⚠️ Fallback MOB=12 for (product=CDLPIL, score=650-) → insufficient data (n_obs=59255, total_ead=23,937)
# ⚠️ Fallback MOB=13 for (product=CDLPIL, score=650-) → insufficient data (n_obs=56365, total_ead=22,592)
# ⚠️ Fallback MOB=14 for (product=CDLPIL, score=650-) → insufficient data (n_obs=55337, total_ead=22,246)
# ⚠️ Fallback MOB=15 for (product=CDLPIL, score=650-) → insufficient data (n_obs=54263, total_ead=21,518)
# ⚠️ Fallback MOB=16 for (product=CDLPIL, score=650-) → insufficient data (n_obs=53791, total_ead=21,491)
# ⚠️ Fallback MOB=17 for (product=CDLPIL, score=650-) → insufficient data (n_obs=53724, total_ead=21,502)
# ⚠️ Fallback MOB=18 for (product=CDLPIL, score=650-) → insufficient data (n_obs=53871, total_ead=21,777)
# ⚠️ Fallback MOB=19 for (product=CDLPIL, score=650-) → insufficient data (n_obs=51742, total_ead=22,435)
# ⚠️ Fallback MOB=20 for (product=CDLPIL, score=650-) → insufficient data (n_obs=50110, total_ead=21,967)
# ⚠️ Fallback MOB=21 for (product=CDLPIL, score=650-) → insufficient data (n_obs=45792, total_ead=20,758)
# ⚠️ Fallback MOB=22 for (product=CDLPIL, score=650-) → insufficient data (n_obs=41750, total_ead=19,499)
# ⚠️ Fallback MOB=23 for (product=CDLPIL, score=650-) → insufficient data (n_obs=37383, total_ead=18,031)
# ⚠️ Fallback MOB=0 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=127090, total_ead=328,558)
# ⚠️ Fallback MOB=1 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=130478, total_ead=285,791)
# ⚠️ Fallback MOB=2 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=132380, total_ead=241,537)
# ⚠️ Fallback MOB=3 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=132121, total_ead=192,804)
# ⚠️ Fallback MOB=4 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=132112, total_ead=144,016)
# ⚠️ Fallback MOB=5 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=130866, total_ead=92,647)
# ⚠️ Fallback MOB=6 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=129119, total_ead=49,012)
# ⚠️ Fallback MOB=7 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=127707, total_ead=40,806)
# ⚠️ Fallback MOB=8 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=125378, total_ead=33,153)
# ⚠️ Fallback MOB=9 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=121784, total_ead=27,148)
# ⚠️ Fallback MOB=10 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=118142, total_ead=24,675)
# ⚠️ Fallback MOB=11 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=114405, total_ead=22,845)
# ⚠️ Fallback MOB=12 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=110205, total_ead=21,193)
# ⚠️ Fallback MOB=13 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=106797, total_ead=20,878)
# ⚠️ Fallback MOB=14 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=96505, total_ead=20,144)
# ⚠️ Fallback MOB=15 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=86955, total_ead=19,467)
# ⚠️ Fallback MOB=16 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=77103, total_ead=18,233)
# ⚠️ Fallback MOB=17 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=68454, total_ead=17,113)
# ⚠️ Fallback MOB=18 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=60139, total_ead=16,101)
# ⚠️ Fallback MOB=19 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=56559, total_ead=16,180)
# ⚠️ Fallback MOB=20 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=51188, total_ead=15,174)
# ⚠️ Fallback MOB=21 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=43831, total_ead=13,517)
# ⚠️ Fallback MOB=22 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=36168, total_ead=11,389)
# ⚠️ Fallback MOB=23 for (product=CDLPIL, score=OTHERS) → insufficient data (n_obs=27501, total_ead=8,742)
# ⚠️ Fallback MOB=0 for (product=SALPIL, score=A) → insufficient data (n_obs=7493, total_ead=133,125)
# ⚠️ Fallback MOB=1 for (product=SALPIL, score=A) → insufficient data (n_obs=8122, total_ead=134,168)
# ⚠️ Fallback MOB=2 for (product=SALPIL, score=A) → insufficient data (n_obs=8931, total_ead=136,766)
# ⚠️ Fallback MOB=3 for (product=SALPIL, score=A) → insufficient data (n_obs=9776, total_ead=139,349)
# ⚠️ Fallback MOB=4 for (product=SALPIL, score=A) → insufficient data (n_obs=10559, total_ead=141,962)
# ⚠️ Fallback MOB=5 for (product=SALPIL, score=A) → insufficient data (n_obs=11169, total_ead=144,233)
# ⚠️ Fallback MOB=6 for (product=SALPIL, score=A) → insufficient data (n_obs=11743, total_ead=146,924)
# ⚠️ Fallback MOB=7 for (product=SALPIL, score=A) → insufficient data (n_obs=12266, total_ead=153,037)
# ⚠️ Fallback MOB=8 for (product=SALPIL, score=A) → insufficient data (n_obs=13413, total_ead=159,643)
# ⚠️ Fallback MOB=9 for (product=SALPIL, score=A) → insufficient data (n_obs=14065, total_ead=159,556)
# ⚠️ Fallback MOB=10 for (product=SALPIL, score=A) → insufficient data (n_obs=14630, total_ead=156,640)
# ⚠️ Fallback MOB=11 for (product=SALPIL, score=A) → insufficient data (n_obs=14917, total_ead=150,662)
# ⚠️ Fallback MOB=12 for (product=SALPIL, score=A) → insufficient data (n_obs=15122, total_ead=145,826)
# ⚠️ Fallback MOB=13 for (product=SALPIL, score=A) → insufficient data (n_obs=15409, total_ead=138,315)
# ⚠️ Fallback MOB=14 for (product=SALPIL, score=A) → insufficient data (n_obs=15232, total_ead=128,943)
# ⚠️ Fallback MOB=15 for (product=SALPIL, score=A) → insufficient data (n_obs=14894, total_ead=117,798)
# ⚠️ Fallback MOB=16 for (product=SALPIL, score=A) → insufficient data (n_obs=14726, total_ead=107,677)
# ⚠️ Fallback MOB=17 for (product=SALPIL, score=A) → insufficient data (n_obs=15124, total_ead=102,989)
# ⚠️ Fallback MOB=18 for (product=SALPIL, score=A) → insufficient data (n_obs=15908, total_ead=99,250)
# ⚠️ Fallback MOB=19 for (product=SALPIL, score=A) → insufficient data (n_obs=16611, total_ead=97,696)
# ⚠️ Fallback MOB=20 for (product=SALPIL, score=A) → insufficient data (n_obs=17376, total_ead=85,569)
# ⚠️ Fallback MOB=21 for (product=SALPIL, score=A) → insufficient data (n_obs=15839, total_ead=71,816)
# ⚠️ Fallback MOB=22 for (product=SALPIL, score=A) → insufficient data (n_obs=14381, total_ead=59,163)
# ⚠️ Fallback MOB=23 for (product=SALPIL, score=A) → insufficient data (n_obs=13070, total_ead=50,359)
# ⚠️ Fallback MOB=24 for (product=SALPIL, score=A) → insufficient data (n_obs=11911, total_ead=44,012)
# ⚠️ Fallback MOB=25 for (product=SALPIL, score=A) → insufficient data (n_obs=10512, total_ead=39,673)
# ⚠️ Fallback MOB=26 for (product=SALPIL, score=A) → insufficient data (n_obs=9399, total_ead=36,769)
# ⚠️ Fallback MOB=27 for (product=SALPIL, score=A) → insufficient data (n_obs=8425, total_ead=34,930)
# ⚠️ Fallback MOB=28 for (product=SALPIL, score=A) → insufficient data (n_obs=7344, total_ead=31,779)
# ⚠️ Fallback MOB=29 for (product=SALPIL, score=A) → insufficient data (n_obs=5877, total_ead=25,147)
# ⚠️ Fallback MOB=0 for (product=SALPIL, score=B) → insufficient data (n_obs=15437, total_ead=276,067)
# ⚠️ Fallback MOB=1 for (product=SALPIL, score=B) → insufficient data (n_obs=16853, total_ead=281,467)
# ⚠️ Fallback MOB=2 for (product=SALPIL, score=B) → insufficient data (n_obs=18311, total_ead=289,143)
# ⚠️ Fallback MOB=3 for (product=SALPIL, score=B) → insufficient data (n_obs=19600, total_ead=296,048)
# ⚠️ Fallback MOB=4 for (product=SALPIL, score=B) → insufficient data (n_obs=20927, total_ead=303,267)
# ⚠️ Fallback MOB=5 for (product=SALPIL, score=B) → insufficient data (n_obs=21998, total_ead=308,724)
# ⚠️ Fallback MOB=6 for (product=SALPIL, score=B) → insufficient data (n_obs=23051, total_ead=316,641)
# ⚠️ Fallback MOB=7 for (product=SALPIL, score=B) → insufficient data (n_obs=23866, total_ead=329,753)
# ⚠️ Fallback MOB=8 for (product=SALPIL, score=B) → insufficient data (n_obs=25860, total_ead=345,171)
# ⚠️ Fallback MOB=9 for (product=SALPIL, score=B) → insufficient data (n_obs=26765, total_ead=348,621)
# ⚠️ Fallback MOB=10 for (product=SALPIL, score=B) → insufficient data (n_obs=27389, total_ead=342,748)
# ⚠️ Fallback MOB=11 for (product=SALPIL, score=B) → insufficient data (n_obs=27121, total_ead=327,604)
# ⚠️ Fallback MOB=12 for (product=SALPIL, score=B) → insufficient data (n_obs=26926, total_ead=318,330)
# ⚠️ Fallback MOB=13 for (product=SALPIL, score=B) → insufficient data (n_obs=26485, total_ead=297,339)
# ⚠️ Fallback MOB=14 for (product=SALPIL, score=B) → insufficient data (n_obs=25692, total_ead=275,529)
# ⚠️ Fallback MOB=15 for (product=SALPIL, score=B) → insufficient data (n_obs=24782, total_ead=255,900)
# ⚠️ Fallback MOB=16 for (product=SALPIL, score=B) → insufficient data (n_obs=24435, total_ead=240,017)
# ⚠️ Fallback MOB=17 for (product=SALPIL, score=B) → insufficient data (n_obs=25273, total_ead=229,837)
# ⚠️ Fallback MOB=18 for (product=SALPIL, score=B) → insufficient data (n_obs=26795, total_ead=223,788)
# ⚠️ Fallback MOB=19 for (product=SALPIL, score=B) → insufficient data (n_obs=28706, total_ead=226,069)
# ⚠️ Fallback MOB=20 for (product=SALPIL, score=B) → insufficient data (n_obs=30598, total_ead=201,978)
# ⚠️ Fallback MOB=21 for (product=SALPIL, score=B) → insufficient data (n_obs=27949, total_ead=176,084)
# ⚠️ Fallback MOB=22 for (product=SALPIL, score=B) → insufficient data (n_obs=25516, total_ead=151,529)
# ⚠️ Fallback MOB=23 for (product=SALPIL, score=B) → insufficient data (n_obs=23679, total_ead=137,513)
# ⚠️ Fallback MOB=24 for (product=SALPIL, score=B) → insufficient data (n_obs=22071, total_ead=129,556)
# ⚠️ Fallback MOB=25 for (product=SALPIL, score=B) → insufficient data (n_obs=20144, total_ead=121,693)
# ⚠️ Fallback MOB=26 for (product=SALPIL, score=B) → insufficient data (n_obs=18526, total_ead=117,143)
# ⚠️ Fallback MOB=27 for (product=SALPIL, score=B) → insufficient data (n_obs=17216, total_ead=114,751)
# ⚠️ Fallback MOB=28 for (product=SALPIL, score=B) → insufficient data (n_obs=15274, total_ead=105,478)
# ⚠️ Fallback MOB=29 for (product=SALPIL, score=B) → insufficient data (n_obs=12316, total_ead=85,630)
# ⚠️ Fallback MOB=0 for (product=SALPIL, score=C) → insufficient data (n_obs=15121, total_ead=274,689)
# ⚠️ Fallback MOB=1 for (product=SALPIL, score=C) → insufficient data (n_obs=16023, total_ead=271,870)
# ⚠️ Fallback MOB=2 for (product=SALPIL, score=C) → insufficient data (n_obs=16876, total_ead=273,009)
# ⚠️ Fallback MOB=3 for (product=SALPIL, score=C) → insufficient data (n_obs=17570, total_ead=273,714)
# ⚠️ Fallback MOB=4 for (product=SALPIL, score=C) → insufficient data (n_obs=18256, total_ead=276,492)
# ⚠️ Fallback MOB=5 for (product=SALPIL, score=C) → insufficient data (n_obs=18942, total_ead=281,783)
# ⚠️ Fallback MOB=6 for (product=SALPIL, score=C) → insufficient data (n_obs=19716, total_ead=289,925)
# ⚠️ Fallback MOB=7 for (product=SALPIL, score=C) → insufficient data (n_obs=20183, total_ead=300,258)
# ⚠️ Fallback MOB=8 for (product=SALPIL, score=C) → insufficient data (n_obs=21633, total_ead=313,089)
# ⚠️ Fallback MOB=9 for (product=SALPIL, score=C) → insufficient data (n_obs=22295, total_ead=319,305)
# ⚠️ Fallback MOB=10 for (product=SALPIL, score=C) → insufficient data (n_obs=22599, total_ead=314,144)
# ⚠️ Fallback MOB=11 for (product=SALPIL, score=C) → insufficient data (n_obs=21878, total_ead=300,365)
# ⚠️ Fallback MOB=12 for (product=SALPIL, score=C) → insufficient data (n_obs=21261, total_ead=290,968)
# ⚠️ Fallback MOB=13 for (product=SALPIL, score=C) → insufficient data (n_obs=20406, total_ead=269,783)
# ⚠️ Fallback MOB=14 for (product=SALPIL, score=C) → insufficient data (n_obs=19385, total_ead=249,152)
# ⚠️ Fallback MOB=15 for (product=SALPIL, score=C) → insufficient data (n_obs=18429, total_ead=234,457)
# ⚠️ Fallback MOB=16 for (product=SALPIL, score=C) → insufficient data (n_obs=18515, total_ead=224,741)
# ⚠️ Fallback MOB=17 for (product=SALPIL, score=C) → insufficient data (n_obs=19773, total_ead=225,098)
# ⚠️ Fallback MOB=18 for (product=SALPIL, score=C) → insufficient data (n_obs=21698, total_ead=225,649)
# ⚠️ Fallback MOB=19 for (product=SALPIL, score=C) → insufficient data (n_obs=23782, total_ead=234,996)
# ⚠️ Fallback MOB=20 for (product=SALPIL, score=C) → insufficient data (n_obs=25486, total_ead=215,652)
# ⚠️ Fallback MOB=21 for (product=SALPIL, score=C) → insufficient data (n_obs=23267, total_ead=190,514)
# ⚠️ Fallback MOB=22 for (product=SALPIL, score=C) → insufficient data (n_obs=21444, total_ead=172,039)
# ⚠️ Fallback MOB=23 for (product=SALPIL, score=C) → insufficient data (n_obs=20412, total_ead=167,518)
# ⚠️ Fallback MOB=24 for (product=SALPIL, score=C) → insufficient data (n_obs=19469, total_ead=166,304)
# ⚠️ Fallback MOB=25 for (product=SALPIL, score=C) → insufficient data (n_obs=18289, total_ead=164,277)
# ⚠️ Fallback MOB=26 for (product=SALPIL, score=C) → insufficient data (n_obs=17286, total_ead=165,694)
# ⚠️ Fallback MOB=27 for (product=SALPIL, score=C) → insufficient data (n_obs=16477, total_ead=170,508)
# ⚠️ Fallback MOB=28 for (product=SALPIL, score=C) → insufficient data (n_obs=14631, total_ead=158,529)
# ⚠️ Fallback MOB=29 for (product=SALPIL, score=C) → insufficient data (n_obs=11684, total_ead=126,307)
# ⚠️ Fallback MOB=0 for (product=SALPIL, score=D) → insufficient data (n_obs=1966, total_ead=37,515)
# ⚠️ Fallback MOB=1 for (product=SALPIL, score=D) → insufficient data (n_obs=2415, total_ead=43,820)
# ⚠️ Fallback MOB=2 for (product=SALPIL, score=D) → insufficient data (n_obs=2847, total_ead=49,647)
# ⚠️ Fallback MOB=3 for (product=SALPIL, score=D) → insufficient data (n_obs=3111, total_ead=52,715)
# ⚠️ Fallback MOB=4 for (product=SALPIL, score=D) → insufficient data (n_obs=3389, total_ead=56,698)
# ⚠️ Fallback MOB=5 for (product=SALPIL, score=D) → insufficient data (n_obs=3694, total_ead=61,461)
# ⚠️ Fallback MOB=6 for (product=SALPIL, score=D) → insufficient data (n_obs=4054, total_ead=67,595)
# ⚠️ Fallback MOB=7 for (product=SALPIL, score=D) → insufficient data (n_obs=4380, total_ead=74,892)
# ⚠️ Fallback MOB=8 for (product=SALPIL, score=D) → insufficient data (n_obs=4953, total_ead=85,173)
# ⚠️ Fallback MOB=9 for (product=SALPIL, score=D) → insufficient data (n_obs=5440, total_ead=94,303)
# ⚠️ Fallback MOB=10 for (product=SALPIL, score=D) → insufficient data (n_obs=5550, total_ead=93,330)
# ⚠️ Fallback MOB=11 for (product=SALPIL, score=D) → insufficient data (n_obs=5280, total_ead=88,604)
# ⚠️ Fallback MOB=12 for (product=SALPIL, score=D) → insufficient data (n_obs=5014, total_ead=83,126)
# ⚠️ Fallback MOB=13 for (product=SALPIL, score=D) → insufficient data (n_obs=4714, total_ead=76,476)
# ⚠️ Fallback MOB=14 for (product=SALPIL, score=D) → insufficient data (n_obs=4390, total_ead=70,498)
# ⚠️ Fallback MOB=15 for (product=SALPIL, score=D) → insufficient data (n_obs=4175, total_ead=68,577)
# ⚠️ Fallback MOB=16 for (product=SALPIL, score=D) → insufficient data (n_obs=4423, total_ead=70,254)
# ⚠️ Fallback MOB=17 for (product=SALPIL, score=D) → insufficient data (n_obs=4980, total_ead=74,342)
# ⚠️ Fallback MOB=18 for (product=SALPIL, score=D) → insufficient data (n_obs=5820, total_ead=81,796)
# ⚠️ Fallback MOB=19 for (product=SALPIL, score=D) → insufficient data (n_obs=6317, total_ead=85,339)
# ⚠️ Fallback MOB=20 for (product=SALPIL, score=D) → insufficient data (n_obs=6600, total_ead=81,400)
# ⚠️ Fallback MOB=21 for (product=SALPIL, score=D) → insufficient data (n_obs=5983, total_ead=72,152)
# ⚠️ Fallback MOB=22 for (product=SALPIL, score=D) → insufficient data (n_obs=5491, total_ead=65,634)
# ⚠️ Fallback MOB=23 for (product=SALPIL, score=D) → insufficient data (n_obs=5311, total_ead=66,583)
# ⚠️ Fallback MOB=24 for (product=SALPIL, score=D) → insufficient data (n_obs=5152, total_ead=68,784)
# ⚠️ Fallback MOB=25 for (product=SALPIL, score=D) → insufficient data (n_obs=4961, total_ead=71,205)
# ⚠️ Fallback MOB=26 for (product=SALPIL, score=D) → insufficient data (n_obs=4801, total_ead=74,168)
# ⚠️ Fallback MOB=27 for (product=SALPIL, score=D) → insufficient data (n_obs=4666, total_ead=78,369)
# ⚠️ Fallback MOB=28 for (product=SALPIL, score=D) → insufficient data (n_obs=4049, total_ead=70,624)
# ⚠️ Fallback MOB=29 for (product=SALPIL, score=D) → insufficient data (n_obs=3090, total_ead=54,701)
# ⚠️ Fallback MOB=0 for (product=SPLPIL, score=500-) → insufficient data (n_obs=2628, total_ead=38,960)
# ⚠️ Fallback MOB=1 for (product=SPLPIL, score=500-) → insufficient data (n_obs=2404, total_ead=32,347)
# ⚠️ Fallback MOB=2 for (product=SPLPIL, score=500-) → insufficient data (n_obs=2226, total_ead=28,060)
# ⚠️ Fallback MOB=3 for (product=SPLPIL, score=500-) → insufficient data (n_obs=2121, total_ead=24,282)
# ⚠️ Fallback MOB=4 for (product=SPLPIL, score=500-) → insufficient data (n_obs=2076, total_ead=23,290)
# ⚠️ Fallback MOB=5 for (product=SPLPIL, score=500-) → insufficient data (n_obs=1898, total_ead=20,081)
# ⚠️ Fallback MOB=6 for (product=SPLPIL, score=500-) → insufficient data (n_obs=1675, total_ead=16,390)
# ⚠️ Fallback MOB=7 for (product=SPLPIL, score=500-) → insufficient data (n_obs=1525, total_ead=14,167)
# ⚠️ Fallback MOB=8 for (product=SPLPIL, score=500-) → insufficient data (n_obs=1391, total_ead=11,870)
# ⚠️ Fallback MOB=9 for (product=SPLPIL, score=500-) → insufficient data (n_obs=1255, total_ead=9,540)
# ⚠️ Fallback MOB=10 for (product=SPLPIL, score=500-) → insufficient data (n_obs=1130, total_ead=7,121)
# ⚠️ Fallback MOB=11 for (product=SPLPIL, score=500-) → insufficient data (n_obs=962, total_ead=4,606)
# ⚠️ Fallback MOB=12 for (product=SPLPIL, score=500-) → insufficient data (n_obs=859, total_ead=3,334)
# ⚠️ Fallback MOB=13 for (product=SPLPIL, score=500-) → insufficient data (n_obs=745, total_ead=2,573)
# ⚠️ Fallback MOB=14 for (product=SPLPIL, score=500-) → insufficient data (n_obs=635, total_ead=1,948)
# ⚠️ Fallback MOB=15 for (product=SPLPIL, score=500-) → insufficient data (n_obs=505, total_ead=1,429)
# ⚠️ Fallback MOB=16 for (product=SPLPIL, score=500-) → insufficient data (n_obs=403, total_ead=1,013)
# ⚠️ Fallback MOB=17 for (product=SPLPIL, score=500-) → insufficient data (n_obs=320, total_ead=794)
# ⚠️ Fallback MOB=18 for (product=SPLPIL, score=500-) → insufficient data (n_obs=257, total_ead=667)
# ⚠️ Fallback MOB=19 for (product=SPLPIL, score=500-) → insufficient data (n_obs=229, total_ead=602)
# ⚠️ Fallback MOB=20 for (product=SPLPIL, score=500-) → insufficient data (n_obs=173, total_ead=539)
# ⚠️ Fallback MOB=21 for (product=SPLPIL, score=500-) → insufficient data (n_obs=124, total_ead=451)
# ⚠️ Fallback MOB=22 for (product=SPLPIL, score=500-) → insufficient data (n_obs=70, total_ead=303)
# ⚠️ Fallback MOB=23 for (product=SPLPIL, score=500-) → insufficient data (n_obs=46, total_ead=175)
# ⚠️ Fallback MOB=0 for (product=SPLPIL, score=550-) → insufficient data (n_obs=762, total_ead=8,187)
# ⚠️ Fallback MOB=1 for (product=SPLPIL, score=550-) → insufficient data (n_obs=785, total_ead=7,139)
# ⚠️ Fallback MOB=2 for (product=SPLPIL, score=550-) → insufficient data (n_obs=833, total_ead=6,402)
# ⚠️ Fallback MOB=3 for (product=SPLPIL, score=550-) → insufficient data (n_obs=901, total_ead=6,183)
# ⚠️ Fallback MOB=4 for (product=SPLPIL, score=550-) → insufficient data (n_obs=938, total_ead=5,907)
# ⚠️ Fallback MOB=5 for (product=SPLPIL, score=550-) → insufficient data (n_obs=953, total_ead=5,458)
# ⚠️ Fallback MOB=6 for (product=SPLPIL, score=550-) → insufficient data (n_obs=999, total_ead=5,104)
# ⚠️ Fallback MOB=7 for (product=SPLPIL, score=550-) → insufficient data (n_obs=988, total_ead=4,629)
# ⚠️ Fallback MOB=8 for (product=SPLPIL, score=550-) → insufficient data (n_obs=1011, total_ead=4,160)
# ⚠️ Fallback MOB=9 for (product=SPLPIL, score=550-) → insufficient data (n_obs=997, total_ead=3,382)
# ⚠️ Fallback MOB=10 for (product=SPLPIL, score=550-) → insufficient data (n_obs=962, total_ead=2,643)
# ⚠️ Fallback MOB=11 for (product=SPLPIL, score=550-) → insufficient data (n_obs=881, total_ead=1,716)
# ⚠️ Fallback MOB=12 for (product=SPLPIL, score=550-) → insufficient data (n_obs=815, total_ead=1,040)
# ⚠️ Fallback MOB=13 for (product=SPLPIL, score=550-) → insufficient data (n_obs=737, total_ead=942)
# ⚠️ Fallback MOB=14 for (product=SPLPIL, score=550-) → insufficient data (n_obs=620, total_ead=740)
# ⚠️ Fallback MOB=15 for (product=SPLPIL, score=550-) → insufficient data (n_obs=504, total_ead=539)
# ⚠️ Fallback MOB=16 for (product=SPLPIL, score=550-) → insufficient data (n_obs=421, total_ead=475)
# ⚠️ Fallback MOB=17 for (product=SPLPIL, score=550-) → insufficient data (n_obs=346, total_ead=460)
# ⚠️ Fallback MOB=18 for (product=SPLPIL, score=550-) → insufficient data (n_obs=245, total_ead=353)
# ⚠️ Fallback MOB=19 for (product=SPLPIL, score=550-) → insufficient data (n_obs=223, total_ead=384)
# ⚠️ Fallback MOB=20 for (product=SPLPIL, score=550-) → insufficient data (n_obs=152, total_ead=248)
# ⚠️ Fallback MOB=21 for (product=SPLPIL, score=550-) → insufficient data (n_obs=93, total_ead=157)
# ⚠️ Fallback MOB=22 for (product=SPLPIL, score=550-) → insufficient data (n_obs=56, total_ead=136)
# ⚠️ Fallback MOB=23 for (product=SPLPIL, score=550-) → insufficient data (n_obs=34, total_ead=55)
# ⚠️ Fallback MOB=0 for (product=SPLPIL, score=600-) → insufficient data (n_obs=799, total_ead=8,182)
# ⚠️ Fallback MOB=1 for (product=SPLPIL, score=600-) → insufficient data (n_obs=850, total_ead=7,580)
# ⚠️ Fallback MOB=2 for (product=SPLPIL, score=600-) → insufficient data (n_obs=929, total_ead=6,925)
# ⚠️ Fallback MOB=3 for (product=SPLPIL, score=600-) → insufficient data (n_obs=968, total_ead=6,150)
# ⚠️ Fallback MOB=4 for (product=SPLPIL, score=600-) → insufficient data (n_obs=996, total_ead=5,629)
# ⚠️ Fallback MOB=5 for (product=SPLPIL, score=600-) → insufficient data (n_obs=1020, total_ead=5,102)
# ⚠️ Fallback MOB=6 for (product=SPLPIL, score=600-) → insufficient data (n_obs=1065, total_ead=4,665)
# ⚠️ Fallback MOB=7 for (product=SPLPIL, score=600-) → insufficient data (n_obs=1052, total_ead=4,003)
# ⚠️ Fallback MOB=8 for (product=SPLPIL, score=600-) → insufficient data (n_obs=1090, total_ead=3,454)
# ⚠️ Fallback MOB=9 for (product=SPLPIL, score=600-) → insufficient data (n_obs=1061, total_ead=2,570)
# ⚠️ Fallback MOB=10 for (product=SPLPIL, score=600-) → insufficient data (n_obs=1018, total_ead=1,978)
# ⚠️ Fallback MOB=11 for (product=SPLPIL, score=600-) → insufficient data (n_obs=943, total_ead=1,233)
# ⚠️ Fallback MOB=12 for (product=SPLPIL, score=600-) → insufficient data (n_obs=865, total_ead=634)
# ⚠️ Fallback MOB=13 for (product=SPLPIL, score=600-) → insufficient data (n_obs=769, total_ead=525)
# ⚠️ Fallback MOB=14 for (product=SPLPIL, score=600-) → insufficient data (n_obs=628, total_ead=476)
# ⚠️ Fallback MOB=15 for (product=SPLPIL, score=600-) → insufficient data (n_obs=517, total_ead=340)
# ⚠️ Fallback MOB=16 for (product=SPLPIL, score=600-) → insufficient data (n_obs=436, total_ead=300)
# ⚠️ Fallback MOB=17 for (product=SPLPIL, score=600-) → insufficient data (n_obs=360, total_ead=313)
# ⚠️ Fallback MOB=18 for (product=SPLPIL, score=600-) → insufficient data (n_obs=252, total_ead=238)
# ⚠️ Fallback MOB=19 for (product=SPLPIL, score=600-) → insufficient data (n_obs=225, total_ead=238)
# ⚠️ Fallback MOB=20 for (product=SPLPIL, score=600-) → insufficient data (n_obs=150, total_ead=182)
# ⚠️ Fallback MOB=21 for (product=SPLPIL, score=600-) → insufficient data (n_obs=99, total_ead=129)
# ⚠️ Fallback MOB=22 for (product=SPLPIL, score=600-) → insufficient data (n_obs=66, total_ead=97)
# ⚠️ Fallback MOB=23 for (product=SPLPIL, score=600-) → insufficient data (n_obs=40, total_ead=58)
# ⚠️ Fallback MOB=0 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1716, total_ead=15,336)
# ⚠️ Fallback MOB=1 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1741, total_ead=13,431)
# ⚠️ Fallback MOB=2 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1706, total_ead=10,887)
# ⚠️ Fallback MOB=3 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1716, total_ead=8,899)
# ⚠️ Fallback MOB=4 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1730, total_ead=7,128)
# ⚠️ Fallback MOB=5 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1742, total_ead=5,436)
# ⚠️ Fallback MOB=6 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1754, total_ead=3,726)
# ⚠️ Fallback MOB=7 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1721, total_ead=3,108)
# ⚠️ Fallback MOB=8 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1727, total_ead=2,471)
# ⚠️ Fallback MOB=9 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1629, total_ead=1,596)
# ⚠️ Fallback MOB=10 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1557, total_ead=1,209)
# ⚠️ Fallback MOB=11 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1429, total_ead=687)
# ⚠️ Fallback MOB=12 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1326, total_ead=365)
# ⚠️ Fallback MOB=13 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1223, total_ead=352)
# ⚠️ Fallback MOB=14 for (product=SPLPIL, score=650+) → insufficient data (n_obs=1087, total_ead=367)
# ⚠️ Fallback MOB=15 for (product=SPLPIL, score=650+) → insufficient data (n_obs=934, total_ead=364)
# ⚠️ Fallback MOB=16 for (product=SPLPIL, score=650+) → insufficient data (n_obs=780, total_ead=305)
# ⚠️ Fallback MOB=17 for (product=SPLPIL, score=650+) → insufficient data (n_obs=651, total_ead=269)
# ⚠️ Fallback MOB=18 for (product=SPLPIL, score=650+) → insufficient data (n_obs=491, total_ead=186)
# ⚠️ Fallback MOB=19 for (product=SPLPIL, score=650+) → insufficient data (n_obs=434, total_ead=163)
# ⚠️ Fallback MOB=20 for (product=SPLPIL, score=650+) → insufficient data (n_obs=345, total_ead=149)
# ⚠️ Fallback MOB=21 for (product=SPLPIL, score=650+) → insufficient data (n_obs=256, total_ead=138)
# ⚠️ Fallback MOB=22 for (product=SPLPIL, score=650+) → insufficient data (n_obs=170, total_ead=122)
# ⚠️ Fallback MOB=23 for (product=SPLPIL, score=650+) → insufficient data (n_obs=118, total_ead=128)
# ⚠️ Fallback MOB=0 for (product=SPLPIL, score=650-) → insufficient data (n_obs=634, total_ead=6,167)
# ⚠️ Fallback MOB=1 for (product=SPLPIL, score=650-) → insufficient data (n_obs=664, total_ead=5,500)
# ⚠️ Fallback MOB=2 for (product=SPLPIL, score=650-) → insufficient data (n_obs=713, total_ead=5,189)
# ⚠️ Fallback MOB=3 for (product=SPLPIL, score=650-) → insufficient data (n_obs=753, total_ead=4,731)
# ⚠️ Fallback MOB=4 for (product=SPLPIL, score=650-) → insufficient data (n_obs=760, total_ead=4,113)
# ⚠️ Fallback MOB=5 for (product=SPLPIL, score=650-) → insufficient data (n_obs=792, total_ead=3,747)
# ⚠️ Fallback MOB=6 for (product=SPLPIL, score=650-) → insufficient data (n_obs=812, total_ead=3,236)
# ⚠️ Fallback MOB=7 for (product=SPLPIL, score=650-) → insufficient data (n_obs=805, total_ead=2,711)
# ⚠️ Fallback MOB=8 for (product=SPLPIL, score=650-) → insufficient data (n_obs=813, total_ead=2,108)
# ⚠️ Fallback MOB=9 for (product=SPLPIL, score=650-) → insufficient data (n_obs=784, total_ead=1,490)
# ⚠️ Fallback MOB=10 for (product=SPLPIL, score=650-) → insufficient data (n_obs=736, total_ead=1,095)
# ⚠️ Fallback MOB=11 for (product=SPLPIL, score=650-) → insufficient data (n_obs=680, total_ead=741)
# ⚠️ Fallback MOB=12 for (product=SPLPIL, score=650-) → insufficient data (n_obs=624, total_ead=432)
# ⚠️ Fallback MOB=13 for (product=SPLPIL, score=650-) → insufficient data (n_obs=554, total_ead=394)
# ⚠️ Fallback MOB=14 for (product=SPLPIL, score=650-) → insufficient data (n_obs=463, total_ead=368)
# ⚠️ Fallback MOB=15 for (product=SPLPIL, score=650-) → insufficient data (n_obs=381, total_ead=295)
# ⚠️ Fallback MOB=16 for (product=SPLPIL, score=650-) → insufficient data (n_obs=324, total_ead=309)
# ⚠️ Fallback MOB=17 for (product=SPLPIL, score=650-) → insufficient data (n_obs=257, total_ead=296)
# ⚠️ Fallback MOB=18 for (product=SPLPIL, score=650-) → insufficient data (n_obs=192, total_ead=182)
# ⚠️ Fallback MOB=19 for (product=SPLPIL, score=650-) → insufficient data (n_obs=160, total_ead=147)
# ⚠️ Fallback MOB=20 for (product=SPLPIL, score=650-) → insufficient data (n_obs=113, total_ead=156)
# ⚠️ Fallback MOB=21 for (product=SPLPIL, score=650-) → insufficient data (n_obs=85, total_ead=94)
# ⚠️ Fallback MOB=22 for (product=SPLPIL, score=650-) → insufficient data (n_obs=52, total_ead=80)
# ⚠️ Fallback MOB=23 for (product=SPLPIL, score=650-) → insufficient data (n_obs=35, total_ead=62)
# ⚠️ Fallback MOB=8 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=1, total_ead=0)
# ⚠️ Fallback MOB=9 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=1, total_ead=0)
# ⚠️ Fallback MOB=10 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=1, total_ead=0)
# ⚠️ Fallback MOB=11 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=1, total_ead=0)
# ⚠️ Fallback MOB=12 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=1, total_ead=0)
# ⚠️ Fallback MOB=13 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=1, total_ead=0)
# ⚠️ Fallback MOB=14 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=1, total_ead=0)
# ⚠️ Fallback MOB=15 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=4, total_ead=4)
# ⚠️ Fallback MOB=16 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=112, total_ead=203)
# ⚠️ Fallback MOB=17 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=211, total_ead=440)
# ⚠️ Fallback MOB=18 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=305, total_ead=718)
# ⚠️ Fallback MOB=19 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=398, total_ead=943)
# ⚠️ Fallback MOB=20 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=422, total_ead=1,052)
# ⚠️ Fallback MOB=21 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=422, total_ead=1,129)
# ⚠️ Fallback MOB=22 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=422, total_ead=1,227)
# ⚠️ Fallback MOB=23 for (product=SPLPIL, score=OTHERS) → insufficient data (n_obs=422, total_ead=1,332)
# ⚠️ Fallback MOB=0 for (product=TOPPIL, score=A) → insufficient data (n_obs=8279, total_ead=149,687)
# ⚠️ Fallback MOB=1 for (product=TOPPIL, score=A) → insufficient data (n_obs=8193, total_ead=138,346)
# ⚠️ Fallback MOB=2 for (product=TOPPIL, score=A) → insufficient data (n_obs=8029, total_ead=126,675)
# ⚠️ Fallback MOB=3 for (product=TOPPIL, score=A) → insufficient data (n_obs=8083, total_ead=121,251)
# ⚠️ Fallback MOB=4 for (product=TOPPIL, score=A) → insufficient data (n_obs=8164, total_ead=114,476)
# ⚠️ Fallback MOB=5 for (product=TOPPIL, score=A) → insufficient data (n_obs=8230, total_ead=109,724)
# ⚠️ Fallback MOB=6 for (product=TOPPIL, score=A) → insufficient data (n_obs=8269, total_ead=104,616)
# ⚠️ Fallback MOB=7 for (product=TOPPIL, score=A) → insufficient data (n_obs=8278, total_ead=101,748)
# ⚠️ Fallback MOB=8 for (product=TOPPIL, score=A) → insufficient data (n_obs=8501, total_ead=96,610)
# ⚠️ Fallback MOB=9 for (product=TOPPIL, score=A) → insufficient data (n_obs=8632, total_ead=90,287)
# ⚠️ Fallback MOB=10 for (product=TOPPIL, score=A) → insufficient data (n_obs=8886, total_ead=87,950)
# ⚠️ Fallback MOB=11 for (product=TOPPIL, score=A) → insufficient data (n_obs=9109, total_ead=85,858)
# ⚠️ Fallback MOB=12 for (product=TOPPIL, score=A) → insufficient data (n_obs=9131, total_ead=82,223)
# ⚠️ Fallback MOB=13 for (product=TOPPIL, score=A) → insufficient data (n_obs=9087, total_ead=76,585)
# ⚠️ Fallback MOB=14 for (product=TOPPIL, score=A) → insufficient data (n_obs=9226, total_ead=71,709)
# ⚠️ Fallback MOB=15 for (product=TOPPIL, score=A) → insufficient data (n_obs=9147, total_ead=66,716)
# ⚠️ Fallback MOB=16 for (product=TOPPIL, score=A) → insufficient data (n_obs=9126, total_ead=61,738)
# ⚠️ Fallback MOB=17 for (product=TOPPIL, score=A) → insufficient data (n_obs=10073, total_ead=62,273)
# ⚠️ Fallback MOB=18 for (product=TOPPIL, score=A) → insufficient data (n_obs=10625, total_ead=61,619)
# ⚠️ Fallback MOB=19 for (product=TOPPIL, score=A) → insufficient data (n_obs=10468, total_ead=59,569)
# ⚠️ Fallback MOB=20 for (product=TOPPIL, score=A) → insufficient data (n_obs=10550, total_ead=54,805)
# ⚠️ Fallback MOB=21 for (product=TOPPIL, score=A) → insufficient data (n_obs=9689, total_ead=49,246)
# ⚠️ Fallback MOB=22 for (product=TOPPIL, score=A) → insufficient data (n_obs=8823, total_ead=42,924)
# ⚠️ Fallback MOB=23 for (product=TOPPIL, score=A) → insufficient data (n_obs=7989, total_ead=37,003)
# ⚠️ Fallback MOB=24 for (product=TOPPIL, score=A) → insufficient data (n_obs=7374, total_ead=34,163)
# ⚠️ Fallback MOB=25 for (product=TOPPIL, score=A) → insufficient data (n_obs=6576, total_ead=31,278)
# ⚠️ Fallback MOB=26 for (product=TOPPIL, score=A) → insufficient data (n_obs=5595, total_ead=26,078)
# ⚠️ Fallback MOB=27 for (product=TOPPIL, score=A) → insufficient data (n_obs=4909, total_ead=23,663)
# ⚠️ Fallback MOB=28 for (product=TOPPIL, score=A) → insufficient data (n_obs=4123, total_ead=20,055)
# ⚠️ Fallback MOB=29 for (product=TOPPIL, score=A) → insufficient data (n_obs=2527, total_ead=10,843)
# ⚠️ Fallback MOB=0 for (product=TOPPIL, score=B) → insufficient data (n_obs=15034, total_ead=228,130)
# ⚠️ Fallback MOB=1 for (product=TOPPIL, score=B) → insufficient data (n_obs=14621, total_ead=208,267)
# ...
# ⚠️ Fallback MOB=12 for (product=TWLPIL, score=600-) → insufficient data (n_obs=10, total_ead=0)
# ⚠️ Fallback MOB=13 for (product=TWLPIL, score=600-) → insufficient data (n_obs=7, total_ead=0)
# ⚠️ Fallback MOB=14 for (product=TWLPIL, score=600-) → insufficient data (n_obs=3, total_ead=0)
# ⚠️ Fallback MOB=0 for (product=TWLPIL, score=650+) → insufficient data (n_obs=106, total_ead=749)
# ⚠️ Fallback MOB=1 for (product=TWLPIL, score=650+) → insufficient data (n_obs=119, total_ead=758)
# ⚠️ Fallback MOB=2 for (product=TWLPIL, score=650+) → insufficient data (n_obs=131, total_ead=768)
# ⚠️ Fallback MOB=3 for (product=TWLPIL, score=650+) → insufficient data (n_obs=137, total_ead=741)
# ⚠️ Fallback MOB=4 for (product=TWLPIL, score=650+) → insufficient data (n_obs=137, total_ead=674)
# ⚠️ Fallback MOB=5 for (product=TWLPIL, score=650+) → insufficient data (n_obs=137, total_ead=570)
# ⚠️ Fallback MOB=6 for (product=TWLPIL, score=650+) → insufficient data (n_obs=133, total_ead=452)
# ⚠️ Fallback MOB=7 for (product=TWLPIL, score=650+) → insufficient data (n_obs=111, total_ead=308)
# ⚠️ Fallback MOB=8 for (product=TWLPIL, score=650+) → insufficient data (n_obs=84, total_ead=205)
# ⚠️ Fallback MOB=9 for (product=TWLPIL, score=650+) → insufficient data (n_obs=62, total_ead=112)
# ⚠️ Fallback MOB=10 for (product=TWLPIL, score=650+) → insufficient data (n_obs=54, total_ead=42)
# ⚠️ Fallback MOB=11 for (product=TWLPIL, score=650+) → insufficient data (n_obs=46, total_ead=16)
# ⚠️ Fallback MOB=12 for (product=TWLPIL, score=650+) → insufficient data (n_obs=31, total_ead=12)
# ⚠️ Fallback MOB=13 for (product=TWLPIL, score=650+) → insufficient data (n_obs=18, total_ead=0)
# ⚠️ Fallback MOB=14 for (product=TWLPIL, score=650+) → insufficient data (n_obs=6, total_ead=0)
# ⚠️ Fallback MOB=0 for (product=TWLPIL, score=650-) → insufficient data (n_obs=66, total_ead=583)
# ⚠️ Fallback MOB=1 for (product=TWLPIL, score=650-) → insufficient data (n_obs=73, total_ead=601)
# ⚠️ Fallback MOB=2 for (product=TWLPIL, score=650-) → insufficient data (n_obs=78, total_ead=644)
# ⚠️ Fallback MOB=3 for (product=TWLPIL, score=650-) → insufficient data (n_obs=82, total_ead=662)
# ⚠️ Fallback MOB=4 for (product=TWLPIL, score=650-) → insufficient data (n_obs=82, total_ead=649)
# ⚠️ Fallback MOB=5 for (product=TWLPIL, score=650-) → insufficient data (n_obs=82, total_ead=615)
# ⚠️ Fallback MOB=6 for (product=TWLPIL, score=650-) → insufficient data (n_obs=77, total_ead=507)
# ⚠️ Fallback MOB=7 for (product=TWLPIL, score=650-) → insufficient data (n_obs=66, total_ead=354)
# ⚠️ Fallback MOB=8 for (product=TWLPIL, score=650-) → insufficient data (n_obs=54, total_ead=253)
# ⚠️ Fallback MOB=9 for (product=TWLPIL, score=650-) → insufficient data (n_obs=44, total_ead=162)
# ⚠️ Fallback MOB=10 for (product=TWLPIL, score=650-) → insufficient data (n_obs=34, total_ead=107)
# ⚠️ Fallback MOB=11 for (product=TWLPIL, score=650-) → insufficient data (n_obs=27, total_ead=72)
# ⚠️ Fallback MOB=12 for (product=TWLPIL, score=650-) → insufficient data (n_obs=16, total_ead=0)
# ⚠️ Fallback MOB=13 for (product=TWLPIL, score=650-) → insufficient data (n_obs=9, total_ead=0)
# ⚠️ Fallback MOB=14 for (product=TWLPIL, score=650-) → insufficient data (n_obs=4, total_ead=0)
# ⚠️ Fallback MOB=0 for (product=TWLPIL, score=OTHERS) → insufficient data (n_obs=1596, total_ead=30,421)
# ⚠️ Fallback MOB=1 for (product=TWLPIL, score=OTHERS) → insufficient data (n_obs=1231, total_ead=22,586)
# ⚠️ Fallback MOB=2 for (product=TWLPIL, score=OTHERS) → insufficient data (n_obs=884, total_ead=15,865)
# ⚠️ Fallback MOB=3 for (product=TWLPIL, score=OTHERS) → insufficient data (n_obs=610, total_ead=10,346)
# ⚠️ Fallback MOB=4 for (product=TWLPIL, score=OTHERS) → insufficient data (n_obs=374, total_ead=6,027)
# ⚠️ Fallback MOB=5 for (product=TWLPIL, score=OTHERS) → insufficient data (n_obs=138, total_ead=1,942)
# ⚠️ Fallback MOB=0 for (product=XSELL, score=A) → insufficient data (n_obs=1422, total_ead=34,640)
# ⚠️ Fallback MOB=1 for (product=XSELL, score=A) → insufficient data (n_obs=1379, total_ead=31,133)
# ⚠️ Fallback MOB=2 for (product=XSELL, score=A) → insufficient data (n_obs=1352, total_ead=27,229)
# ⚠️ Fallback MOB=3 for (product=XSELL, score=A) → insufficient data (n_obs=1330, total_ead=24,807)
# ⚠️ Fallback MOB=4 for (product=XSELL, score=A) → insufficient data (n_obs=1288, total_ead=22,450)
# ⚠️ Fallback MOB=5 for (product=XSELL, score=A) → insufficient data (n_obs=1253, total_ead=19,895)
# ⚠️ Fallback MOB=6 for (product=XSELL, score=A) → insufficient data (n_obs=1190, total_ead=17,151)
# ⚠️ Fallback MOB=7 for (product=XSELL, score=A) → insufficient data (n_obs=1167, total_ead=16,484)
# ⚠️ Fallback MOB=8 for (product=XSELL, score=A) → insufficient data (n_obs=1171, total_ead=15,404)
# ⚠️ Fallback MOB=9 for (product=XSELL, score=A) → insufficient data (n_obs=1179, total_ead=13,657)
# ⚠️ Fallback MOB=10 for (product=XSELL, score=A) → insufficient data (n_obs=1189, total_ead=12,805)
# ⚠️ Fallback MOB=11 for (product=XSELL, score=A) → insufficient data (n_obs=1242, total_ead=12,550)
# ⚠️ Fallback MOB=12 for (product=XSELL, score=A) → insufficient data (n_obs=1514, total_ead=14,166)
# ⚠️ Fallback MOB=13 for (product=XSELL, score=A) → insufficient data (n_obs=1796, total_ead=15,801)
# ⚠️ Fallback MOB=14 for (product=XSELL, score=A) → insufficient data (n_obs=2119, total_ead=17,456)
# ⚠️ Fallback MOB=15 for (product=XSELL, score=A) → insufficient data (n_obs=2283, total_ead=18,058)
# ⚠️ Fallback MOB=16 for (product=XSELL, score=A) → insufficient data (n_obs=2491, total_ead=19,189)
# ⚠️ Fallback MOB=17 for (product=XSELL, score=A) → insufficient data (n_obs=2790, total_ead=20,039)
# ⚠️ Fallback MOB=18 for (product=XSELL, score=A) → insufficient data (n_obs=2903, total_ead=20,640)
# ⚠️ Fallback MOB=19 for (product=XSELL, score=A) → insufficient data (n_obs=3076, total_ead=21,384)
# ⚠️ Fallback MOB=20 for (product=XSELL, score=A) → insufficient data (n_obs=3900, total_ead=23,048)
# ⚠️ Fallback MOB=21 for (product=XSELL, score=A) → insufficient data (n_obs=3777, total_ead=23,078)
# ⚠️ Fallback MOB=22 for (product=XSELL, score=A) → insufficient data (n_obs=3664, total_ead=22,862)
# ⚠️ Fallback MOB=23 for (product=XSELL, score=A) → insufficient data (n_obs=3517, total_ead=22,356)
# ⚠️ Fallback MOB=24 for (product=XSELL, score=A) → insufficient data (n_obs=3153, total_ead=19,155)
# ⚠️ Fallback MOB=25 for (product=XSELL, score=A) → insufficient data (n_obs=2766, total_ead=16,817)
# ⚠️ Fallback MOB=26 for (product=XSELL, score=A) → insufficient data (n_obs=2301, total_ead=12,597)
# ⚠️ Fallback MOB=27 for (product=XSELL, score=A) → insufficient data (n_obs=2022, total_ead=10,002)
# ⚠️ Fallback MOB=28 for (product=XSELL, score=A) → insufficient data (n_obs=1726, total_ead=7,213)
# ⚠️ Fallback MOB=29 for (product=XSELL, score=A) → insufficient data (n_obs=1338, total_ead=5,433)
# ⚠️ Fallback MOB=0 for (product=XSELL, score=B) → insufficient data (n_obs=3761, total_ead=83,418)
# ⚠️ Fallback MOB=1 for (product=XSELL, score=B) → insufficient data (n_obs=3486, total_ead=69,772)
# ⚠️ Fallback MOB=2 for (product=XSELL, score=B) → insufficient data (n_obs=3326, total_ead=59,548)
# ⚠️ Fallback MOB=3 for (product=XSELL, score=B) → insufficient data (n_obs=3217, total_ead=53,857)
# ⚠️ Fallback MOB=4 for (product=XSELL, score=B) → insufficient data (n_obs=3107, total_ead=47,651)
# ⚠️ Fallback MOB=5 for (product=XSELL, score=B) → insufficient data (n_obs=2981, total_ead=42,422)
# ⚠️ Fallback MOB=6 for (product=XSELL, score=B) → insufficient data (n_obs=2859, total_ead=37,374)
# ⚠️ Fallback MOB=7 for (product=XSELL, score=B) → insufficient data (n_obs=2788, total_ead=35,841)
# ⚠️ Fallback MOB=8 for (product=XSELL, score=B) → insufficient data (n_obs=2680, total_ead=30,595)
# ⚠️ Fallback MOB=9 for (product=XSELL, score=B) → insufficient data (n_obs=2606, total_ead=27,180)
# ⚠️ Fallback MOB=10 for (product=XSELL, score=B) → insufficient data (n_obs=2614, total_ead=25,500)
# ⚠️ Fallback MOB=11 for (product=XSELL, score=B) → insufficient data (n_obs=2617, total_ead=24,200)
# ⚠️ Fallback MOB=12 for (product=XSELL, score=B) → insufficient data (n_obs=2876, total_ead=25,213)
# ⚠️ Fallback MOB=13 for (product=XSELL, score=B) → insufficient data (n_obs=3182, total_ead=26,864)
# ⚠️ Fallback MOB=14 for (product=XSELL, score=B) → insufficient data (n_obs=3513, total_ead=28,262)
# ⚠️ Fallback MOB=15 for (product=XSELL, score=B) → insufficient data (n_obs=3710, total_ead=28,877)
# ⚠️ Fallback MOB=16 for (product=XSELL, score=B) → insufficient data (n_obs=3888, total_ead=29,216)
# ⚠️ Fallback MOB=17 for (product=XSELL, score=B) → insufficient data (n_obs=4202, total_ead=29,898)
# ⚠️ Fallback MOB=18 for (product=XSELL, score=B) → insufficient data (n_obs=4359, total_ead=30,190)
# ⚠️ Fallback MOB=19 for (product=XSELL, score=B) → insufficient data (n_obs=4720, total_ead=31,911)
# ⚠️ Fallback MOB=20 for (product=XSELL, score=B) → insufficient data (n_obs=4881, total_ead=32,534)
# ⚠️ Fallback MOB=21 for (product=XSELL, score=B) → insufficient data (n_obs=4671, total_ead=32,492)
# ⚠️ Fallback MOB=22 for (product=XSELL, score=B) → insufficient data (n_obs=4455, total_ead=31,820)
# ⚠️ Fallback MOB=23 for (product=XSELL, score=B) → insufficient data (n_obs=4182, total_ead=30,927)
# ⚠️ Fallback MOB=24 for (product=XSELL, score=B) → insufficient data (n_obs=3721, total_ead=27,366)
# ⚠️ Fallback MOB=25 for (product=XSELL, score=B) → insufficient data (n_obs=3174, total_ead=23,266)
# ⚠️ Fallback MOB=26 for (product=XSELL, score=B) → insufficient data (n_obs=2550, total_ead=16,392)
# ⚠️ Fallback MOB=27 for (product=XSELL, score=B) → insufficient data (n_obs=2120, total_ead=12,580)
# ⚠️ Fallback MOB=28 for (product=XSELL, score=B) → insufficient data (n_obs=1706, total_ead=8,425)
# ⚠️ Fallback MOB=29 for (product=XSELL, score=B) → insufficient data (n_obs=1197, total_ead=5,117)
# ⚠️ Fallback MOB=0 for (product=XSELL, score=C) → insufficient data (n_obs=6575, total_ead=129,780)
# ⚠️ Fallback MOB=1 for (product=XSELL, score=C) → insufficient data (n_obs=6000, total_ead=106,017)
# ⚠️ Fallback MOB=2 for (product=XSELL, score=C) → insufficient data (n_obs=5490, total_ead=86,708)
# ⚠️ Fallback MOB=3 for (product=XSELL, score=C) → insufficient data (n_obs=5219, total_ead=76,572)
# ⚠️ Fallback MOB=4 for (product=XSELL, score=C) → insufficient data (n_obs=4908, total_ead=65,522)
# ⚠️ Fallback MOB=5 for (product=XSELL, score=C) → insufficient data (n_obs=4664, total_ead=57,705)
# ⚠️ Fallback MOB=6 for (product=XSELL, score=C) → insufficient data (n_obs=4467, total_ead=50,251)
# ⚠️ Fallback MOB=7 for (product=XSELL, score=C) → insufficient data (n_obs=4397, total_ead=48,432)
# ⚠️ Fallback MOB=8 for (product=XSELL, score=C) → insufficient data (n_obs=4316, total_ead=42,354)
# ⚠️ Fallback MOB=9 for (product=XSELL, score=C) → insufficient data (n_obs=4273, total_ead=37,928)
# ⚠️ Fallback MOB=10 for (product=XSELL, score=C) → insufficient data (n_obs=4271, total_ead=34,995)
# ⚠️ Fallback MOB=11 for (product=XSELL, score=C) → insufficient data (n_obs=4268, total_ead=32,413)
# ⚠️ Fallback MOB=12 for (product=XSELL, score=C) → insufficient data (n_obs=4539, total_ead=32,217)
# ⚠️ Fallback MOB=13 for (product=XSELL, score=C) → insufficient data (n_obs=4816, total_ead=32,988)
# ⚠️ Fallback MOB=14 for (product=XSELL, score=C) → insufficient data (n_obs=5003, total_ead=32,449)
# ⚠️ Fallback MOB=15 for (product=XSELL, score=C) → insufficient data (n_obs=5132, total_ead=31,832)
# ⚠️ Fallback MOB=16 for (product=XSELL, score=C) → insufficient data (n_obs=5323, total_ead=32,069)
# ⚠️ Fallback MOB=17 for (product=XSELL, score=C) → insufficient data (n_obs=5573, total_ead=32,941)
# ⚠️ Fallback MOB=18 for (product=XSELL, score=C) → insufficient data (n_obs=5675, total_ead=32,856)
# ⚠️ Fallback MOB=19 for (product=XSELL, score=C) → insufficient data (n_obs=6198, total_ead=34,975)
# ⚠️ Fallback MOB=20 for (product=XSELL, score=C) → insufficient data (n_obs=6323, total_ead=34,680)
# ⚠️ Fallback MOB=21 for (product=XSELL, score=C) → insufficient data (n_obs=5922, total_ead=33,739)
# ⚠️ Fallback MOB=22 for (product=XSELL, score=C) → insufficient data (n_obs=5539, total_ead=32,432)
# ⚠️ Fallback MOB=23 for (product=XSELL, score=C) → insufficient data (n_obs=5112, total_ead=30,262)
# ⚠️ Fallback MOB=24 for (product=XSELL, score=C) → insufficient data (n_obs=4524, total_ead=26,887)
# ⚠️ Fallback MOB=25 for (product=XSELL, score=C) → insufficient data (n_obs=3879, total_ead=23,093)
# ⚠️ Fallback MOB=26 for (product=XSELL, score=C) → insufficient data (n_obs=3267, total_ead=18,283)
# ⚠️ Fallback MOB=27 for (product=XSELL, score=C) → insufficient data (n_obs=2758, total_ead=15,033)
# ⚠️ Fallback MOB=28 for (product=XSELL, score=C) → insufficient data (n_obs=2236, total_ead=10,797)
# ⚠️ Fallback MOB=29 for (product=XSELL, score=C) → insufficient data (n_obs=1688, total_ead=7,346)
# ⚠️ Fallback MOB=0 for (product=XSELL, score=D) → insufficient data (n_obs=9240, total_ead=147,850)
# ⚠️ Fallback MOB=1 for (product=XSELL, score=D) → insufficient data (n_obs=8456, total_ead=128,483)
# ⚠️ Fallback MOB=2 for (product=XSELL, score=D) → insufficient data (n_obs=7844, total_ead=111,703)
# ⚠️ Fallback MOB=3 for (product=XSELL, score=D) → insufficient data (n_obs=7403, total_ead=98,034)
# ⚠️ Fallback MOB=4 for (product=XSELL, score=D) → insufficient data (n_obs=6988, total_ead=83,727)
# ⚠️ Fallback MOB=5 for (product=XSELL, score=D) → insufficient data (n_obs=6679, total_ead=74,491)
# ⚠️ Fallback MOB=6 for (product=XSELL, score=D) → insufficient data (n_obs=6421, total_ead=63,116)
# ⚠️ Fallback MOB=7 for (product=XSELL, score=D) → insufficient data (n_obs=6544, total_ead=62,429)
# ⚠️ Fallback MOB=8 for (product=XSELL, score=D) → insufficient data (n_obs=6848, total_ead=58,282)
# ⚠️ Fallback MOB=9 for (product=XSELL, score=D) → insufficient data (n_obs=7180, total_ead=54,046)
# ⚠️ Fallback MOB=10 for (product=XSELL, score=D) → insufficient data (n_obs=7484, total_ead=52,607)
# ⚠️ Fallback MOB=11 for (product=XSELL, score=D) → insufficient data (n_obs=7836, total_ead=49,989)
# ⚠️ Fallback MOB=12 for (product=XSELL, score=D) → insufficient data (n_obs=8295, total_ead=49,941)
# ⚠️ Fallback MOB=13 for (product=XSELL, score=D) → insufficient data (n_obs=8688, total_ead=50,609)
# ⚠️ Fallback MOB=14 for (product=XSELL, score=D) → insufficient data (n_obs=8848, total_ead=49,024)
# ⚠️ Fallback MOB=15 for (product=XSELL, score=D) → insufficient data (n_obs=8985, total_ead=48,007)
# ⚠️ Fallback MOB=16 for (product=XSELL, score=D) → insufficient data (n_obs=9440, total_ead=50,151)
# ⚠️ Fallback MOB=17 for (product=XSELL, score=D) → insufficient data (n_obs=9855, total_ead=52,362)
# ⚠️ Fallback MOB=18 for (product=XSELL, score=D) → insufficient data (n_obs=10184, total_ead=54,198)
# ⚠️ Fallback MOB=19 for (product=XSELL, score=D) → insufficient data (n_obs=11044, total_ead=58,868)
# ⚠️ Fallback MOB=20 for (product=XSELL, score=D) → insufficient data (n_obs=11280, total_ead=60,946)
# ⚠️ Fallback MOB=21 for (product=XSELL, score=D) → insufficient data (n_obs=10357, total_ead=58,751)
# ⚠️ Fallback MOB=22 for (product=XSELL, score=D) → insufficient data (n_obs=9578, total_ead=56,648)
# ⚠️ Fallback MOB=23 for (product=XSELL, score=D) → insufficient data (n_obs=8637, total_ead=52,604)
# ⚠️ Fallback MOB=24 for (product=XSELL, score=D) → insufficient data (n_obs=7717, total_ead=47,713)
# ⚠️ Fallback MOB=25 for (product=XSELL, score=D) → insufficient data (n_obs=6850, total_ead=44,514)
# ⚠️ Fallback MOB=26 for (product=XSELL, score=D) → insufficient data (n_obs=5990, total_ead=38,654)
# ⚠️ Fallback MOB=27 for (product=XSELL, score=D) → insufficient data (n_obs=5256, total_ead=34,996)
# ⚠️ Fallback MOB=28 for (product=XSELL, score=D) → insufficient data (n_obs=4254, total_ead=26,987)
# ⚠️ Fallback MOB=29 for (product=XSELL, score=D) → insufficient data (n_obs=3380, total_ead=22,115)
# ✅ Generated 153 MOB-level matrices across products (real + fallback).
# 🔹 Ma trận REAL     : 5
# 🔸 Ma trận FALLBACK : 716
# 🔢 Tổng             : 721
# ✅ Xuất file transition thành công → D:\Python_code\RR_model_1711\outputs\Transition_ByProduct_MOB_Score_2.xlsx

# %%
export_transition_excel(
    matrices_by_mob,
    parent_fallback,
    out_path=OUT_ROOT / "Transition_ByProduct_MOB_Score_2.xlsx"
)
# Out:
# ✅ Xuất file transition thành công → D:\Python_code\RR_model_1711\outputs\Transition_ByProduct_MOB_Score_2.xlsx

# %%
# matrices_by_mob đã build từ module transition
# df = raw data chứa DISB_DATE, CUTOFF, MOB, PRINCIPLE_OUTSTANDING, STATE...

from src.rollrate.forecast import forecast_all_vintages

# %%
forecast_results = forecast_all_vintages(
    df_raw=df,
    matrices_by_mob=matrices_by_mob,
    max_mob=29,
    enable_macro=False
)
# Out:
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-03-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-04-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-05-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-06-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-07-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-08-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-09-01 00:00:00) due to error:
#     'OTHERS'

# %%
from src.rollrate.lifecycle import (
    get_actual_all_vintages_amount,
    combine_all_lifecycle_amount,
    lifecycle_to_long_df_amount,
    build_full_lifecycle_amount,
    tag_forecast_rows_amount,
    add_del_metrics,
    aggregate_loss_to_product,
    aggregate_to_product,
    make_metric_pivot,
    export_lifecycle_all_products_one_file,
    aggregate_products_to_portfolio,
    extend_actual_info_with_portfolio
)

# %%
# # 1) Build lifecycle actual + forecast
# df_lifecycle = build_full_lifecycle_amount(df, matrices_by_mob, max_mob=29)

# # 2) Tag forecast
# df_lifecycle_tagged = tag_forecast_rows_amount(df_lifecycle, df)

# # 3) DEL30/60/90
# df_del = add_del_metrics(df_lifecycle_tagged, df)

# # 4) Aggregate lên Product
# df_del_prod = aggregate_to_product(df_del)

# # 5) Pivot lifecycle DEL30+
# df_del30_pivot = df_del_prod.pivot_table(
#     index="VINTAGE_DATE",
#     columns="MOB",
#     values="DEL30_PCT"
# ).fillna(0)

# df_del30_pivot.index.name = "Cohort"

# # 6) Actual max MOB (để kẻ đường đỏ)
# actual_info = (
#     df.groupby("DISBURSAL_DATE")["MOB"]
#     .max()
#     .to_dict()
# )

# # 7) Export Excel đầy đủ format
# export_heatmap(
#     df_pivot=df_del30_pivot,
#     df_del_prod=df_del_prod,
#     actual_info=actual_info,
#     filename="DEL30P_Lifecycle.xlsx"
# )

# print("🎉 Lifecycle DEL30+ đã xuất thành công!")

# %%
# # 1) Build lifecycle (actual + forecast, amount-based)
# df_lifecycle = build_full_lifecycle_amount(
#     df_raw=df,
#     matrices_by_mob=matrices_by_mob,
#     max_mob=29,
# )

# # 2) Tag forecast rows
# df_lifecycle_tagged = tag_forecast_rows_amount(
#     df_lifecycle=df_lifecycle,
#     df_raw=df,
# )

# # 3) Tính DEL30/60/90 amount + pct
# df_del = add_del_metrics(
#     df_lifecycle=df_lifecycle_tagged,
#     df_raw=df,
# )

# # 4) Aggregate Product_Score → Product
# df_del_prod = aggregate_to_product(df_del)

# # 5) Max actual MOB per (Product, Vintage)
# actual_info = (
#     df.groupby(["PRODUCT_TYPE", "DISBURSAL_DATE"])["MOB"]
#       .max()
#       .to_dict()
# )

# # 6) Export chung 1 file, nhiều sheet (mỗi Product × metric)
# export_lifecycle_all_products_one_file(
#     df_del_prod=df_del_prod,
#     actual_info=actual_info,
#     filename="Lifecycle_All_Products.xlsx",
# )

# %%
# # 6) Export chung 1 file, nhiều sheet (mỗi Product × metric)
# export_lifecycle_all_products_one_file(
#     df_del_prod=df_del_prod,
#     actual_info=actual_info,
#     filename="Lifecycle_UnSecured.xlsx",
# )

# %% [markdown]
# ## New pipeline

# %%
# 1. Build lifecycle
df_lifecycle = build_full_lifecycle_amount(df, matrices_by_mob, max_mob=29)

# 2. Tag forecast rows
df_lifecycle = tag_forecast_rows_amount(df_lifecycle, df)

# 3. Add DEL metrics (level Product × Score × Vintage × MOB)
df_del = add_del_metrics(df_lifecycle, df)

# 4. Aggregate lên Product level
df_del_prod = aggregate_to_product(df_del)
# Out:
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-03-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-04-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-05-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-06-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-07-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-08-01 00:00:00) due to error:
#     'OTHERS'
# ⚠️ Skip (TWLPIL, OTHERS, vintage=2025-09-01 00:00:00) due to error:
#     'OTHERS'
# D:\Python_code\RR_model_1711\src\rollrate\lifecycle.py:371: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: pd.Series({

# %%
# 5. Aggregate lên portfolio
df_portfolio = aggregate_products_to_portfolio(
    df_del_prod,
    portfolio_name="PORTFOLIO_ALL"   # hoặc tên tuỳ bạn
)

# 6. Gộp lại: product + portfolio
df_export = pd.concat(
    [df_del_prod, df_portfolio],
    ignore_index=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 5. Aggregate lên portfolio
# ----> 2 df_portfolio = aggregate_products_to_portfolio(
#       3     df_del_prod,
#       4     portfolio_name="PORTFOLIO_ALL"   # hoặc tên tuỳ bạn
#       5 )
#       7 # 6. Gộp lại: product + portfolio
#       8 df_export = pd.concat(
#       9     [df_del_prod, df_portfolio],
#      10     ignore_index=True
#      11 )
#
# NameError: name 'aggregate_products_to_portfolio' is not defined

# %%
# 5) Max actual MOB per (Product, Vintage)
actual_info = (
    df.groupby(["PRODUCT_TYPE", "DISBURSAL_DATE"])["MOB"]
      .max()
      .to_dict()
)

# %%
# 5. Aggregate lên portfolio
df_portfolio = aggregate_products_to_portfolio(
    df_del_prod,
    portfolio_name="PORTFOLIO_ALL"   # hoặc tên tuỳ bạn
)

# 6. Gộp lại: product + portfolio
df_export = pd.concat(
    [df_del_prod, df_portfolio],
    ignore_index=True
)
# Out:
# D:\Python_code\RR_model_1711\src\rollrate\lifecycle.py:437: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(

# %%
actual_info_extended = extend_actual_info_with_portfolio(
    actual_info_prod=actual_info,
    portfolio_name="PORTFOLIO_ALL"
)

export_lifecycle_all_products_one_file(
    df_del_prod=df_export,
    actual_info=actual_info_extended,
    filename="Lifecycle_All_Products_And_Portfolio.xlsx"
)
# Out:
# ✔ Export lifecycle multi-product thành công → Lifecycle_All_Products_And_Portfolio.xlsx

# %%
export_lifecycle_all_products_one_file(
    df_del_prod=df_export,
    actual_info=actual_info_extended,
    filename="Lifecycle_All_Products_And_Portfolio.xlsx"
)
# Out:
# ✔ Export lifecycle multi-product thành công → Lifecycle_All_Products_And_Portfolio.xlsx

# %% [markdown]
# ## sale plan

# %%
from src.rollrate.forecast_plan import forecast_sale_plan_by_mob

# %%
# Chuẩn hóa RISK_SCORE
def normalize_score(x):
    if pd.isna(x):
        return "ALL"
    x_str = str(x).strip().upper()
    if x_str in ["", "NA", "NAN", "NONE", "NULL"]:
        return "ALL"
    return x_str

sale_plan_df["RISK_SCORE"] = sale_plan_df["RISK_SCORE"].apply(normalize_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 10
#       7         return "ALL"
#       8     return x_str
# ---> 10 sale_plan_df["RISK_SCORE"] = sale_plan_df["RISK_SCORE"].apply(normalize_score)
#
# NameError: name 'sale_plan_df' is not defined

# %%
sale_plan_df = pd.read_excel("C:/Users/User/RR_model/sale_plan.xlsx", sheet_name="SALE_PLAN")
sale_plan_df["VINTAGE_DATE"] = pd.to_datetime(sale_plan_df["VINTAGE_DATE"])

print("✔ Sale Plan loaded:")
display(sale_plan_df.head())


# ========================================
# 4) Forecast sale plan dùng matrices_by_mob thực tế
# ========================================
from src.config import BUCKETS_CANON, ABSORBING_BASE

states = list(dict.fromkeys(list(BUCKETS_CANON) + list(ABSORBING_BASE)))

# Xử lý SCORE an toàn
score_raw = row.get("RISK_SCORE", row.get("SCORE", None))

# Đồng nhất tất cả NA, NaN, None, 'NA', 'NAN', 'null', '' → "ALL"
if pd.isna(score_raw):
    score = "ALL"
else:
    score_str = str(score_raw).strip().upper()
    if score_str in ["", "NA", "NAN", "NONE", "NULL"]:
        score = "ALL"
    else:
        score = score_str


print("✔ Forecast completed! Sample:")
display(sale_plan_fc.head(10))

# %%
import pandas as pd
import numpy as np

# Load sale plan
sale_plan_df = pd.read_excel(
    "C:/Users/User/RR_model/sale_plan.xlsx",
    sheet_name="SALE_PLAN"
)
sale_plan_df["VINTAGE_DATE"] = pd.to_datetime(sale_plan_df["VINTAGE_DATE"])

print("✔ Sale Plan loaded:")
display(sale_plan_df.head())

# ========================================
#  ⚠️ NORMALIZE SCORE – ĐÂY LÀ CHỖ SỬA QUAN TRỌNG
# ========================================

def normalize_score(x):
    # pd.NA, np.nan, None --> ALL
    if pd.isna(x):
        return "ALL"
    x_str = str(x).strip().upper()
    # string "NA", "NAN", "" -> ALL
    if x_str in ["", "NA", "NAN", "NONE", "NULL"]:
        return "ALL"
    return x_str

sale_plan_df["RISK_SCORE"] = sale_plan_df["RISK_SCORE"].apply(normalize_score)
print("✔ SCORE normalized:")
display(sale_plan_df.head())

# %%
from src.rollrate.transition import compute_transition_by_mob, STATE_SPACE
from src.config import BUCKETS_CANON



sale_plan_fc = forecast_sale_plan_by_mob(
    sale_plan_df=sale_plan_df,
    matrices_by_mob=matrices_by_mob,
    parent_fallback=parent_fallback,
    mob_target=12,
    start_state=BUCKETS_CANON[0],
    states=STATE_SPACE,
)

# %%
import pandas as pd
import numpy as np

from src.config import BUCKETS_CANON, ABSORBING_BASE
from src.rollrate.transition import compute_transition_by_mob, STATE_SPACE
from src.rollrate.forecast_plan import forecast_sale_plan_by_mob  # hàm bạn đặt trong forecast_plan.py


# ========================================
# 2) Load SALE PLAN + chuẩn hóa SCORE
# ========================================
sale_plan_df = pd.read_excel(
    "C:/Users/User/RR_model/sale_plan.xlsx",
    sheet_name="SALE_PLAN"
)
sale_plan_df["VINTAGE_DATE"] = pd.to_datetime(sale_plan_df["VINTAGE_DATE"])

print("✔ Sale Plan loaded:")
display(sale_plan_df.head())

# Chuẩn hóa RISK_SCORE
def normalize_score(x):
    if pd.isna(x):
        return "ALL"
    x_str = str(x).strip().upper()
    if x_str in ["", "NA", "NAN", "NONE", "NULL"]:
        return "ALL"
    return x_str

sale_plan_df["RISK_SCORE"] = sale_plan_df["RISK_SCORE"].apply(normalize_score)

print("✔ SCORE normalized:")
display(sale_plan_df["RISK_SCORE"].value_counts(dropna=False))

# ========================================
# 3) Forecast SALE PLAN
# ========================================
states = list(STATE_SPACE)  # dùng đúng state_space của engine

sale_plan_fc = forecast_sale_plan_by_mob(
    sale_plan_df=sale_plan_df,
    matrices_by_mob=matrices_by_mob,
    parent_fallback=parent_fallback,
    mob_target=12,
    start_state=BUCKETS_CANON[0],
    states=states,
)

print("✔ Forecast completed! Sample:")
display(sale_plan_fc.head(10))
